# %%
data_20_KV_323=[]
with open("20_KV_323.txt") as f:
    for line in f:
        data_20_KV_323.append([float(x) for x in line.split()])
#data_20_KV_323[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_323[0],data_20_KV_323[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 323',fontsize=20)

max = max(data_20_KV_323[0])/1000
print(max)
# Out:
# 159.968

# %%
data_20_KV_324=[]
with open("20_KV_324.txt") as f:
    for line in f:
        data_20_KV_324.append([float(x) for x in line.split()])
data_20_KV_324[1][0]


from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_324[0],data_20_KV_324[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 324',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 324')

# %%
data_20_KV_325=[]
with open("20_KV_325.txt") as f:
    for line in f:
        data_20_KV_325.append([float(x) for x in line.split()])
data_20_KV_325[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_325[0],data_20_KV_325[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 325',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 325')

# %%
data_20_KV_326=[]
with open("20_KV_326.txt") as f:
    for line in f:
        data_20_KV_326.append([float(x) for x in line.split()])
data_20_KV_326[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_326[0],data_20_KV_326[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 326',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 326')

# %%
data_20_KV_327=[]
with open("20_KV_327.txt") as f:
    for line in f:
        data_20_KV_327.append([float(x) for x in line.split()])
data_20_KV_327[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_327[0],data_20_KV_327[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 327',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 327')

# %%
data_20_KV_328=[]
with open("20_KV_328.txt") as f:
    for line in f:
        data_20_KV_328.append([float(x) for x in line.split()])
data_20_KV_328[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_328[0],data_20_KV_328[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 328',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 328')

# %%
data_20_KV_329=[]
with open("20_KV_329.txt") as f:
    for line in f:
        data_20_KV_329.append([float(x) for x in line.split()])
data_20_KV_329[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_329[0],data_20_KV_329[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 329',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 329')

# %%
data_20_KV_330=[]
with open("20_KV_330.txt") as f:
    for line in f:
        data_20_KV_330.append([float(x) for x in line.split()])
data_20_KV_330[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_330[0],data_20_KV_330[1])
xlabel(r'$us$')
ylabel(r'$Амплитуда(относ. ед.)$')
#x/1000
# Out:
# Text(0.5, 1.0, '20 KV, run 330')

# %%
data_20_KV_331=[]
with open("20_KV_331.txt") as f:
    for line in f:
        data_20_KV_331.append([float(x) for x in line.split()])
data_20_KV_331[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_331[0],data_20_KV_331[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 331',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 331')

# %%
data_20_KV_332=[]
with open("20_KV_332.txt") as f:
    for line in f:
        data_20_KV_332.append([float(x) for x in line.split()])
data_20_KV_332[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_332[0],data_20_KV_332[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 332',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 332')

# %%
data_20_KV_333=[]
with open("20_KV_333.txt") as f:
    for line in f:
        data_20_KV_333.append([float(x) for x in line.split()])
data_20_KV_333[1][0]

from matplotlib.pyplot import (title,legend, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_333[0],data_20_KV_333[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 333',fontsize=20)
# Out:
# Text(0.5, 1.0, '20 KV, run 333')

# %%
data_20_KV_334=[]
with open("20_KV_334.txt") as f:
    for line in f:
        data_20_KV_334.append([float(x) for x in line.split()])
data_20_KV_334[1][0]

from matplotlib.pyplot import (title,legend, savefig, xlabel,ylabel,xticks,yticks, xscale,yscale,text,grid,plot,scatter,errorbar,hist,polar,contour,contourf,colorbar,clabel,imshow)
plot(data_20_KV_334[0],data_20_KV_334[1])
xlabel(r'$us$')
ylabel(r'$V$')
title(r'20 KV, run 334',fontsize=20)

savefig('20kV_run_334.pdf', bbox_inches='tight', format='pdf')
